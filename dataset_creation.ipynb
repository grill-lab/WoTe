# %% [markdown]
# ## Dataset creation
#
# This notebook illustrates how we went from the original Wizard-of-Tasks dataset to WoTe.

# %% [markdown]
# ### Loading in raw WoT

# %%
# get WoT data - https://registry.opendata.aws/wizard-of-tasks/

import os
import subprocess
import pandas as pd

if not os.path.isdir('original_WoT_test'):
    subprocess.run(['aws', 's3', 'cp', 's3://wizard-of-tasks', './original_WoT_test', '--recursive'])
# Out:
# download: s3://wizard-of-tasks/wizard_of_tasks_cooking_v1.0.json to original_WoT_test/wizard_of_tasks_cooking_v1.0.json
# download: s3://wizard-of-tasks/wizard_of_tasks_diy_v1.0.json to original_WoT_test/wizard_of_tasks_diy_v1.0.json
# download: s3://wizard-of-tasks/README.md to original_WoT_test/README.md

# %%
wot_og_df_cooking = pd.read_json('./original_WoT/wizard_of_tasks_cooking_v1.0.json', orient='index')
print(len(wot_og_df_cooking))
wot_og_df_diy = pd.read_json('./original_WoT/wizard_of_tasks_diy_v1.0.json', orient='index')
print(len(wot_og_df_diy))

# concat both
wot_og_df = pd.concat([wot_og_df_cooking, wot_og_df_diy])
wot_og_df.reset_index(inplace=True)
wot_og_df.rename(columns={'index': 'conversation_id'}, inplace=True)

wot_og_df
# Out:
# 272
# 277
#             conversation_id  \
# 0     Wizard-of-Task-food-1
# 1     Wizard-of-Task-food-2
# 2     Wizard-of-Task-food-3
# 3     Wizard-of-Task-food-4
# 4     Wizard-of-Task-food-5
# ..                      ...
# 544  Wizard-of-Task-diy-273
# 545  Wizard-of-Task-diy-274
# 546  Wizard-of-Task-diy-275
# 547  Wizard-of-Task-diy-276
# 548  Wizard-of-Task-diy-277
#
#                                           document_url data_split  \
# 0    https://www.wholefoodsmarket.com/recipes/labne...       test
# 1    https://www.wholefoodsmarket.com/recipes/cream...      train
# 2    https://www.wholefoodsmarket.com/recipes/citru...      train
# 3    https://www.wholefoodsmarket.com/recipes/grill...      train
# 4    https://www.wholefoodsmarket.com/recipes/pasta...      train
# ..                                                 ...        ...
# 544              https://www.wikihow.com/Prune-Dahlias      train
# 545             https://www.wikihow.com/Prune-Begonias      train
# 546               https://www.wikihow.com/Test-a-Diode      train
# 547            https://www.wikihow.com/Melt-a-Soap-Bar      train
# 548      https://www.wikihow.com/Plant-Sprouted-Onions      train
#
#                                                  turns
# 0    [{'text': 'Hi! I love labneh but I've never mi...
# 1    [{'text': 'How much cream cheese and other ing...
# 2    [{'text': 'Will I be using premade pasta from ...
# 3    [{'text': 'Will I be making the tortellini by ...
# 4    [{'text': 'Will I be making my own pasta for t...
# ..                                                 ...
# 544  [{'text': 'What does it mean to prune a plant?...
# 545  [{'text': 'Will I need anything besides prunin...
# 546  [{'text': 'Would you be able to tell me what a...
# 547  [{'text': 'Are there tools needed for this pro...
# 548  [{'text': 'I like onions and want to sprout an...
#
# [549 rows x 4 columns]

# %%
# iterate through each row in wot_og_df and iterate through each turn in the turns column to get all the turns
# append each turn to a list
# create a new dataframe with the list

import numpy as np

turns_list = []
for index, row in wot_og_df.iterrows():
    history = [f"{turn['role']}: {turn['text']}" for turn in row['turns']]
    # replace all None values with empty string
    history = ["" if pd.isna(turn) else turn for turn in history]
    for i, turn in enumerate(row['turns']):
        if len(history) != 0 and len(history) >= i:
            if i > 4:
                turn['history'] = " | ".join(history[i-4:i])
            else:
                turn['history'] = " | ".join(history[:i])
        else:
            turn['history'] = ""
        turn['conversation_id'] = row['conversation_id']
        turn['document_url'] = row['document_url']
        turn['domain'] = "food" if "food" in turn['conversation_id'] else "diy"
        turns_list.append(turn)

turns_df = pd.DataFrame(turns_list)

# %%
turns_df
# Out:
#                                                     text  turn_counter  \
# 0      Hi! I love labneh but I've never mixed it with...             1
# 1                Here are the ingredients you will need!             2
# 2      After I've chopped all of the herbs and gather...             3
# 3                        Yes. I've shared the step below             4
# 4      The ingredients are now mixed. What should be ...             5
# ...                                                  ...           ...
# 18072   Great, is there anything else that I need to do?            29
# 18073  Now you just wait to enjoy your delicious home...            30
# 18074  How long does onions take to fully grow before...            31
# 18075  It will take between 60-80 days. Keep an eye o...            32
# 18076                               Thanks for the help!            33
#
#                                          dangerous_tools  \
# 0                                                     []
# 1                                                     []
# 2      [1 teaspoon lemon zest, 1 teaspoon chopped fre...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 18072                                                 []
# 18073                                                 []
# 18074                                                 []
# 18075                                                 []
# 18076                                                 []
#
#                                              shared_data  \
# 0                                                     []
# 1      [2 cups plain Greek yogurt, 1 tablespoon extra...
# 2                                                     []
# 3      [Transfer to a bowl. Add oil, tarragon, basil,...
# 4                                                     []
# ...                                                  ...
# 18072                                                 []
# 18073                                                 []
# 18074                                                 []
# 18075                                                 []
# 18076                                                 []
#
#                                intent  \
# 0      ask_question_ingredients_tools
# 1       return_list_ingredients_tools
# 2                   request_next_step
# 3                    return_next_step
# 4                   request_next_step
# ...                               ...
# 18072               request_next_step
# 18073    answer_question_recipe_steps
# 18074       ask_question_recipe_steps
# 18075                return_next_step
# 18076                            stop
#
#                                         real_life_action relevant useful  \
# 0                                                    N/A      yes    yes
# 1                                                    NaN      yes    yes
# 2      I would gather and prepare all of the ingredie...      yes    yes
# 3                                                    NaN      yes    yes
# 4                   I will mix the ingredients together.      yes     no
# ...                                                  ...      ...    ...
# 18072                                                n/a      yes    yes
# 18073                                                NaN      yes    yes
# 18074                     wait for onions to fuly grown       yes    yes
# 18075                                                NaN      yes    yes
# 18076     I would keep an eye on the onions as directed.      yes    yes
#
#        worker_id  previous_worker_id     role  \
# 0            111                 NaN  student
# 1            121               111.0  teacher
# 2            105               121.0  student
# 3            129               105.0  teacher
# 4             24               129.0  student
# ...          ...                 ...      ...
# 18072          3                16.0  student
# 18073        112                 3.0  teacher
# 18074          9               112.0  student
# 18075         16                 9.0  teacher
# 18076          3                16.0  student
#
#                                                  history  \
# 0
# 1      student: Hi! I love labneh but I've never mixe...
# 2      student: Hi! I love labneh but I've never mixe...
# 3      student: Hi! I love labneh but I've never mixe...
# 4      student: Hi! I love labneh but I've never mixe...
# ...                                                  ...
# 18072  student: I've got a few that seem ready to har...
# 18073  teacher: To get them out of the ground, just p...
# 18074  student: How much of the plant can I eat once ...
# 18075  teacher: You must not eat the roots, shoots or...
# 18076  student: Great, is there anything else that I ...
#
#               conversation_id  \
# 0       Wizard-of-Task-food-1
# 1       Wizard-of-Task-food-1
# 2       Wizard-of-Task-food-1
# 3       Wizard-of-Task-food-1
# 4       Wizard-of-Task-food-1
# ...                       ...
# 18072  Wizard-of-Task-diy-277
# 18073  Wizard-of-Task-diy-277
# 18074  Wizard-of-Task-diy-277
# 18075  Wizard-of-Task-diy-277
# 18076  Wizard-of-Task-diy-277
#
#                                             document_url domain external_urls
# 0      https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# 1      https://www.wholefoodsmarket.com/recipes/labne...   food            []
# 2      https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# 3      https://www.wholefoodsmarket.com/recipes/labne...   food            []
# 4      https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# ...                                                  ...    ...           ...
# 18072      https://www.wikihow.com/Plant-Sprouted-Onions    diy           NaN
# 18073      https://www.wikihow.com/Plant-Sprouted-Onions    diy            []
# 18074      https://www.wikihow.com/Plant-Sprouted-Onions    diy           NaN
# 18075      https://www.wikihow.com/Plant-Sprouted-Onions    diy            []
# 18076      https://www.wikihow.com/Plant-Sprouted-Onions    diy           NaN
#
# [18077 rows x 16 columns]

# %% [markdown]
# ### Filtering process

# %% [markdown]
# Step 1: Remove non question utterances. We keep all questions where the intent contains "ask" or the corresponding answer contains "answer_question_recipe_steps"

# %%
qa_df = turns_df[(turns_df['intent'].str.contains('ask')) & (turns_df['intent'] != 'ask_student_question')]
print(qa_df['intent'].unique())
qa_indices = qa_df.index.values
# get indices of rows that are not in ask but response is of intent = answer_question_recipe_steps
answer_indices = turns_df[(turns_df['intent'] == 'answer_question_recipe_steps')].index.values
missing_qa = [a-1 for a in answer_indices if a-1 not in qa_indices]

qa_indices = np.concatenate((qa_indices, missing_qa))
qa_df = turns_df.iloc[qa_indices]

qa_df.reset_index(inplace=True)
qa_df.rename(columns={'index': 'turn_id'}, inplace=True)
qa_df
# Out:
# ['ask_question_ingredients_tools' 'ask_question_recipe_steps']
# /var/folders/_x/cz945mds7flgypjf31gb0blr0000gn/T/ipykernel_29340/449655916.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qa_df.rename(columns={'index': 'turn_id'}, inplace=True)
#       turn_id                                               text  \
# 0           0  Hi! I love labneh but I've never mixed it with...
# 1           8  Can I let the ingredients sit for longer to ma...
# 2          12           Do you think I could freeze this recipe?
# 3          19  How much cream cheese and other ingredients wi...
# 4          21                What are the few other ingredients?
# ...       ...                                                ...
# 4474    17725  What should I do besides caring for it on a we...
# 4475    17782  I have pruned just above the leaf node, is the...
# 4476    17838  I'll keep that in mind going forward, then. Ar...
# 4477    17912  Gotcha!  Any words of advice to share before w...
# 4478    18072   Great, is there anything else that I need to do?
#
#       turn_counter                     dangerous_tools shared_data  \
# 0                1                                  []          []
# 1                9                                  []          []
# 2               13                                  []          []
# 3                1                                  []          []
# 4                3  [1 package cream cheese, softened]          []
# ...            ...                                 ...         ...
# 4474            51                                  []          []
# 4475            21                                  []          []
# 4476            44                                  []          []
# 4477            27                                  []          []
# 4478            29                                  []          []
#
#                               intent  \
# 0     ask_question_ingredients_tools
# 1          ask_question_recipe_steps
# 2          ask_question_recipe_steps
# 3     ask_question_ingredients_tools
# 4          ask_question_recipe_steps
# ...                              ...
# 4474               request_next_step
# 4475               request_next_step
# 4476               request_next_step
# 4477                        chitchat
# 4478               request_next_step
#
#                                    real_life_action relevant useful  \
# 0                                               N/A      yes    yes
# 1     I would let the ingredients sit to marinate.       yes     no
# 2               I would get out my salt and pepper.       no     no
# 3                                               N/A      yes    yes
# 4                      Take it out all ingredients.      yes    yes
# ...                                             ...      ...    ...
# 4474                              ask for next step      yes    yes
# 4475                     I would prune as directed.      yes    yes
# 4476      I will make note to prune my tree yearly.      yes    yes
# 4477                                 ask for advice      yes    yes
# 4478                                            n/a      yes    yes
#
#       worker_id  previous_worker_id     role  \
# 0           111                 NaN  student
# 1             2               142.0  student
# 2             2                68.0  student
# 3           203                 NaN  student
# 4           228               129.0  student
# ...         ...                 ...      ...
# 4474         49                28.0  student
# 4475          3                16.0  student
# 4476        142                44.0  student
# 4477         49                62.0  student
# 4478          3                16.0  student
#
#                                                 history  \
# 0
# 1     student: The ingredients are now mixed. What s...
# 2     student: Can I let the ingredients sit for lon...
# 3
# 4     student: How much cream cheese and other ingre...
# ...                                                 ...
# 4474  student: Ok, to be clear, I shouldn't touch or...
# 4475  student: Thanks, I think I already did that pr...
# 4476  student: I have pruned as directed, what shoul...
# 4477  student: How much water should I give at each ...
# 4478  student: I've got a few that seem ready to har...
#
#              conversation_id  \
# 0      Wizard-of-Task-food-1
# 1      Wizard-of-Task-food-1
# 2      Wizard-of-Task-food-1
# 3      Wizard-of-Task-food-2
# 4      Wizard-of-Task-food-2
# ...                      ...
# 4474  Wizard-of-Task-diy-266
# 4475  Wizard-of-Task-diy-269
# 4476  Wizard-of-Task-diy-270
# 4477  Wizard-of-Task-diy-272
# 4478  Wizard-of-Task-diy-277
#
#                                            document_url domain external_urls
# 0     https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# 1     https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# 2     https://www.wholefoodsmarket.com/recipes/labne...   food           NaN
# 3     https://www.wholefoodsmarket.com/recipes/cream...   food           NaN
# 4     https://www.wholefoodsmarket.com/recipes/cream...   food           NaN
# ...                                                 ...    ...           ...
# 4474             https://www.wikihow.com/Grow-Java-Moss    diy           NaN
# 4475          https://www.wikihow.com/Prune-Honeysuckle    diy           NaN
# 4476    https://www.wikihow.com/Prune-a-Leyland-Cypress    diy           NaN
# 4477   https://www.wikihow.com/Grow-English-Ivy-Indoors    diy           NaN
# 4478      https://www.wikihow.com/Plant-Sprouted-Onions    diy           NaN
#
# [4479 rows x 17 columns]

# %%
# get indexes of rows in turns_df that are in qa_df
answer_indicies = [i+1 for i in qa_indices]
answers_df = turns_df[turns_df.index.isin(answer_indicies)]
answers_df.reset_index(inplace=True)
answers_df.rename(columns={'index': 'turn_id'}, inplace=True)
answers_df
# Out:
# /var/folders/_x/cz945mds7flgypjf31gb0blr0000gn/T/ipykernel_29340/1215925644.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   answers_df.rename(columns={'index': 'turn_id'}, inplace=True)
#       turn_id                                               text  \
# 0           1            Here are the ingredients you will need!
# 1           9  Only 15 minutes is needed for the flavors to m...
# 2          13                                               None
# 3          20  You will need 1 package of cream cheese and a ...
# 4          22  I attached them to my last message.  They are ...
# ...       ...                                                ...
# 4474    18059  One inch is the amount of water. It's a measur...
# 4475    18063  There is not much you can do as weeds growing ...
# 4476    18071  You must not eat the roots, shoots or the skin...
# 4477    18073  Now you just wait to enjoy your delicious home...
# 4478    18075  It will take between 60-80 days. Keep an eye o...
#
#       turn_counter dangerous_tools  \
# 0                2              []
# 1               10              []
# 2               14              []
# 3                2              []
# 4                4              []
# ...            ...             ...
# 4474            16              []
# 4475            20              []
# 4476            28              []
# 4477            30              []
# 4478            32              []
#
#                                             shared_data  \
# 0     [2 cups plain Greek yogurt, 1 tablespoon extra...
# 1                                                    []
# 2                                                    []
# 3     [1 package cream cheese, softened, 1/2  cup sm...
# 4                                                    []
# ...                                                 ...
# 4474                                                 []
# 4475                                                 []
# 4476                                                 []
# 4477                                                 []
# 4478                                                 []
#
#                              intent real_life_action relevant useful  \
# 0     return_list_ingredients_tools              NaN      yes    yes
# 1      answer_question_recipe_steps              NaN      yes    yes
# 2     answer_question_external_fact              NaN       no     no
# 3      answer_question_recipe_steps              NaN      yes    yes
# 4      answer_question_recipe_steps              NaN      yes    yes
# ...                             ...              ...      ...    ...
# 4474  answer_question_external_fact              NaN      yes    yes
# 4475  answer_question_external_fact              NaN      yes    yes
# 4476               return_next_step              NaN      yes    yes
# 4477   answer_question_recipe_steps              NaN      yes    yes
# 4478               return_next_step              NaN      yes    yes
#
#       worker_id  previous_worker_id     role  \
# 0           121               111.0  teacher
# 1            22                 2.0  teacher
# 2           132                 2.0  teacher
# 3           129               203.0  teacher
# 4           121               228.0  teacher
# ...         ...                 ...      ...
# 4474        154               124.0  teacher
# 4475         24                78.0  teacher
# 4476         16               149.0  teacher
# 4477        112                 3.0  teacher
# 4478         16                 9.0  teacher
#
#                                                 history  \
# 0     student: Hi! I love labneh but I've never mixe...
# 1     teacher: None | student: Once the ingredients ...
# 2     teacher: Only 15 minutes is needed for the fla...
# 3     student: How much cream cheese and other ingre...
# 4     student: How much cream cheese and other ingre...
# ...                                                 ...
# 4474  teacher: Now plant the sprouts 1 inch deep in ...
# 4475  teacher: One inch is the amount of water. It's...
# 4476  teacher: You want to look for signs that the o...
# 4477  teacher: To get them out of the ground, just p...
# 4478  teacher: You must not eat the roots, shoots or...
#
#              conversation_id  \
# 0      Wizard-of-Task-food-1
# 1      Wizard-of-Task-food-1
# 2      Wizard-of-Task-food-1
# 3      Wizard-of-Task-food-2
# 4      Wizard-of-Task-food-2
# ...                      ...
# 4474  Wizard-of-Task-diy-277
# 4475  Wizard-of-Task-diy-277
# 4476  Wizard-of-Task-diy-277
# 4477  Wizard-of-Task-diy-277
# 4478  Wizard-of-Task-diy-277
#
#                                            document_url domain  \
# 0     https://www.wholefoodsmarket.com/recipes/labne...   food
# 1     https://www.wholefoodsmarket.com/recipes/labne...   food
# 2     https://www.wholefoodsmarket.com/recipes/labne...   food
# 3     https://www.wholefoodsmarket.com/recipes/cream...   food
# 4     https://www.wholefoodsmarket.com/recipes/cream...   food
# ...                                                 ...    ...
# 4474      https://www.wikihow.com/Plant-Sprouted-Onions    diy
# 4475      https://www.wikihow.com/Plant-Sprouted-Onions    diy
# 4476      https://www.wikihow.com/Plant-Sprouted-Onions    diy
# 4477      https://www.wikihow.com/Plant-Sprouted-Onions    diy
# 4478      https://www.wikihow.com/Plant-Sprouted-Onions    diy
#
#                                           external_urls
# 0                                                    []
# 1                                                    []
# 2     [recently visited search engines will be added...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4474                                                 []
# 4475                                                 []
# 4476                                                 []
# 4477                                                 []
# 4478                                                 []
#
# [4479 rows x 17 columns]

# %%
# combine each same index of qa_df and answers_df into one row
qa_pairs_df = pd.concat([qa_df.add_suffix('_question'), answers_df.add_suffix('_answer')], axis=1)
qa_pairs_df.columns
# Out:
# Index(['turn_id_question', 'text_question', 'turn_counter_question',
#        'dangerous_tools_question', 'shared_data_question', 'intent_question',
#        'real_life_action_question', 'relevant_question', 'useful_question',
#        'worker_id_question', 'previous_worker_id_question', 'role_question',
#        'history_question', 'conversation_id_question', 'document_url_question',
#        'domain_question', 'external_urls_question', 'turn_id_answer',
#        'text_answer', 'turn_counter_answer', 'dangerous_tools_answer',
#        'shared_data_answer', 'intent_answer', 'real_life_action_answer',
#        'relevant_answer', 'useful_answer', 'worker_id_answer',
#        'previous_worker_id_answer', 'role_answer', 'history_answer',
#        'conversation_id_answer', 'document_url_answer', 'domain_answer',
#        'external_urls_answer'],
#       dtype='object')

# %%
qa_pairs_df.drop(columns=[
    'turn_id_answer', 'conversation_id_answer', 'document_url_answer',  
    'worker_id_answer', 'worker_id_question', 'turn_id_question', 'turn_counter_question', 'dangerous_tools_question', 
    'shared_data_question', 'previous_worker_id_question', 'role_question', 'external_urls_question', 'turn_counter_answer',
    'previous_worker_id_answer', 'role_answer', 'external_urls_question', 'shared_data_answer', 'dangerous_tools_answer', 'history_answer'
    ], inplace=True)
qa_pairs_df = qa_pairs_df.rename(columns={'data_split_question': 'data_split', 'conversation_id_question': 'conversation_id'})

# %%
# the question_id should be the index of the number of questions in the conversation_id
qa_pairs_df['question_count'] = qa_pairs_df.groupby('conversation_id')['conversation_id'].cumcount()
qa_pairs_df['question_id'] = qa_pairs_df['conversation_id'].str.split('Wizard-of-Task-').str[1]
qa_pairs_df['question_id'] = qa_pairs_df['question_id'] + '-' + qa_pairs_df['question_count'].astype(str)
qa_pairs_df
# Out:
#                                           text_question  \
# 0     Hi! I love labneh but I've never mixed it with...
# 1     Can I let the ingredients sit for longer to ma...
# 2              Do you think I could freeze this recipe?
# 3     How much cream cheese and other ingredients wi...
# 4                   What are the few other ingredients?
# ...                                                 ...
# 4474  What should I do besides caring for it on a we...
# 4475  I have pruned just above the leaf node, is the...
# 4476  I'll keep that in mind going forward, then. Ar...
# 4477  Gotcha!  Any words of advice to share before w...
# 4478   Great, is there anything else that I need to do?
#
#                      intent_question  \
# 0     ask_question_ingredients_tools
# 1          ask_question_recipe_steps
# 2          ask_question_recipe_steps
# 3     ask_question_ingredients_tools
# 4          ask_question_recipe_steps
# ...                              ...
# 4474               request_next_step
# 4475               request_next_step
# 4476               request_next_step
# 4477                        chitchat
# 4478               request_next_step
#
#                           real_life_action_question relevant_question  \
# 0                                               N/A               yes
# 1     I would let the ingredients sit to marinate.                yes
# 2               I would get out my salt and pepper.                no
# 3                                               N/A               yes
# 4                      Take it out all ingredients.               yes
# ...                                             ...               ...
# 4474                              ask for next step               yes
# 4475                     I would prune as directed.               yes
# 4476      I will make note to prune my tree yearly.               yes
# 4477                                 ask for advice               yes
# 4478                                            n/a               yes
#
#      useful_question                                   history_question  \
# 0                yes
# 1                 no  student: The ingredients are now mixed. What s...
# 2                 no  student: Can I let the ingredients sit for lon...
# 3                yes
# 4                yes  student: How much cream cheese and other ingre...
# ...              ...                                                ...
# 4474             yes  student: Ok, to be clear, I shouldn't touch or...
# 4475             yes  student: Thanks, I think I already did that pr...
# 4476             yes  student: I have pruned as directed, what shoul...
# 4477             yes  student: How much water should I give at each ...
# 4478             yes  student: I've got a few that seem ready to har...
#
#              conversation_id  \
# 0      Wizard-of-Task-food-1
# 1      Wizard-of-Task-food-1
# 2      Wizard-of-Task-food-1
# 3      Wizard-of-Task-food-2
# 4      Wizard-of-Task-food-2
# ...                      ...
# 4474  Wizard-of-Task-diy-266
# 4475  Wizard-of-Task-diy-269
# 4476  Wizard-of-Task-diy-270
# 4477  Wizard-of-Task-diy-272
# 4478  Wizard-of-Task-diy-277
#
#                                   document_url_question domain_question  \
# 0     https://www.wholefoodsmarket.com/recipes/labne...            food
# 1     https://www.wholefoodsmarket.com/recipes/labne...            food
# 2     https://www.wholefoodsmarket.com/recipes/labne...            food
# 3     https://www.wholefoodsmarket.com/recipes/cream...            food
# 4     https://www.wholefoodsmarket.com/recipes/cream...            food
# ...                                                 ...             ...
# 4474             https://www.wikihow.com/Grow-Java-Moss             diy
# 4475          https://www.wikihow.com/Prune-Honeysuckle             diy
# 4476    https://www.wikihow.com/Prune-a-Leyland-Cypress             diy
# 4477   https://www.wikihow.com/Grow-English-Ivy-Indoors             diy
# 4478      https://www.wikihow.com/Plant-Sprouted-Onions             diy
#
#                                             text_answer  \
# 0               Here are the ingredients you will need!
# 1     Only 15 minutes is needed for the flavors to m...
# 2                                                  None
# 3     You will need 1 package of cream cheese and a ...
# 4     I attached them to my last message.  They are ...
# ...                                                 ...
# 4474  One inch is the amount of water. It's a measur...
# 4475  There is not much you can do as weeds growing ...
# 4476  You must not eat the roots, shoots or the skin...
# 4477  Now you just wait to enjoy your delicious home...
# 4478  It will take between 60-80 days. Keep an eye o...
#
#                       intent_answer real_life_action_answer relevant_answer  \
# 0     return_list_ingredients_tools                     NaN             yes
# 1      answer_question_recipe_steps                     NaN             yes
# 2     answer_question_external_fact                     NaN              no
# 3      answer_question_recipe_steps                     NaN             yes
# 4      answer_question_recipe_steps                     NaN             yes
# ...                             ...                     ...             ...
# 4474  answer_question_external_fact                     NaN             yes
# 4475  answer_question_external_fact                     NaN             yes
# 4476               return_next_step                     NaN             yes
# 4477   answer_question_recipe_steps                     NaN             yes
# 4478               return_next_step                     NaN             yes
#
#      useful_answer domain_answer  \
# 0              yes          food
# 1              yes          food
# 2               no          food
# 3              yes          food
# 4              yes          food
# ...            ...           ...
# 4474           yes           diy
# 4475           yes           diy
# 4476           yes           diy
# 4477           yes           diy
# 4478           yes           diy
#
#                                    external_urls_answer  question_count  \
# 0                                                    []               0
# 1                                                    []               1
# 2     [recently visited search engines will be added...               2
# 3                                                    []               0
# 4                                                    []               1
# ...                                                 ...             ...
# 4474                                                 []              12
# 4475                                                 []               6
# 4476                                                 []              15
# 4477                                                 []               9
# 4478                                                 []               6
#
#      question_id
# 0       food-1-0
# 1       food-1-1
# 2       food-1-2
# 3       food-2-0
# 4       food-2-1
# ...          ...
# 4474  diy-266-12
# 4475   diy-269-6
# 4476  diy-270-15
# 4477   diy-272-9
# 4478   diy-277-6
#
# [4479 rows x 18 columns]

# %% [markdown]
# Remove all questions that are:
# - remove all that are not questions
# - are not useful/ relevant
# - not ask_question_recipe_steps
# - drop all external questions

# %%
qa_pairs_df['intent_answer'].unique()
# Out:
# array(['return_list_ingredients_tools', 'answer_question_recipe_steps',
#        'answer_question_external_fact', 'return_next_step',
#        'ask_student_question', 'chitchat', 'request_next_step',
#        'ask_question_recipe_steps', 'ask_question_ingredients_tools',
#        'misc', 'stop'], dtype=object)

# %%
# drop all rows where neither intent_question contains ask or intent_answer contains answer
print(len(qa_pairs_df))
filtered_qa_pairs_df = qa_pairs_df[~(~(qa_pairs_df['intent_question'].str.contains('ask')) & ~(qa_pairs_df['intent_answer'].str.contains('answer')))]
print(len(filtered_qa_pairs_df))
# drop all chit chat
filtered_qa_pairs_df = filtered_qa_pairs_df[~filtered_qa_pairs_df['intent_answer'].str.contains('chitchat')]
print(len(filtered_qa_pairs_df))
# Out:
# 4479
# 4382
# 4351

# %%
# drop all questions that have len(external_urls_answer) > 0
internal_questions = filtered_qa_pairs_df[filtered_qa_pairs_df['intent_answer']=='answer_question_recipe_steps']
external_answer = filtered_qa_pairs_df[filtered_qa_pairs_df['intent_answer']=='answer_question_external_fact']
external_link = filtered_qa_pairs_df[filtered_qa_pairs_df['external_urls_answer'].str.len() != 0]
# get the not overlapping elements of internal_questions and external_link
internal_questions = internal_questions[~internal_questions['question_id'].isin(external_link['question_id'])]

# get the not overlapping elements of external_answer and external_link
individuals = external_answer[~external_answer['question_id'].isin(external_link['question_id'])]

print(f'External links: {len(external_link)}')
print(f'External answers: {len(external_answer)}')
print('-----')
print(f'External questions: {len(external_link) + len(individuals)}')
print(f'Internal questions: {len(internal_questions)}')
# Out:
# External links: 610
# External answers: 1543
# -----
# External questions: 1820
# Internal questions: 1589

# %%
# drop all not useful/ relevant questions
internal_questions = internal_questions[(internal_questions['relevant_question']== "yes") & (internal_questions['useful_question']== "yes")]
len(internal_questions)
# Out:
# 1337

# %%
internal_questions = internal_questions.drop(columns=['relevant_answer', 'useful_answer', 'external_urls_answer', 
    'relevant_question', 'useful_question', 'real_life_action_question', 'real_life_action_answer', 'question_count'])
internal_questions = internal_questions.rename(columns={'text_question': 'question', 'history_question': 'history'})
internal_questions
# Out:
#                                                question  \
# 3     How much cream cheese and other ingredients wi...
# 4                   What are the few other ingredients?
# 5     Will I be using premade pasta from the box or ...
# 6           Okay and what other ingredients do I need?
# 10    Should the tortellini be fresh or can I use fr...
# ...                                                 ...
# 4461         Clean your fabric in the washer and dryer.
# 4463  Spray cypress and peppermint oils under and ar...
# 4471  My verbena is so overgrown, I need to prune. w...
# 4473  Okay, that makes sense. Alright then, I've pla...
# 4477  Gotcha!  Any words of advice to share before w...
#
#                      intent_question  \
# 3     ask_question_ingredients_tools
# 4          ask_question_recipe_steps
# 5     ask_question_ingredients_tools
# 6     ask_question_ingredients_tools
# 10         ask_question_recipe_steps
# ...                              ...
# 4461                return_next_step
# 4463                return_next_step
# 4471                        chitchat
# 4473               request_next_step
# 4477                        chitchat
#
#                                                 history  \
# 3
# 4     student: How much cream cheese and other ingre...
# 5
# 6     student: Will I be using premade pasta from th...
# 10    student: Will I be making the tortellini by ha...
# ...                                                 ...
# 4461  teacher: You will now remove it and rinse it w...
# 4463  teacher: Spray roach repellent.  | student: I ...
# 4471
# 4473  student: I have cut off pieces as directed, wh...
# 4477  student: How much water should I give at each ...
#
#              conversation_id  \
# 3      Wizard-of-Task-food-2
# 4      Wizard-of-Task-food-2
# 5      Wizard-of-Task-food-3
# 6      Wizard-of-Task-food-3
# 10     Wizard-of-Task-food-4
# ...                      ...
# 4461  Wizard-of-Task-diy-250
# 4463  Wizard-of-Task-diy-252
# 4471  Wizard-of-Task-diy-265
# 4473  Wizard-of-Task-diy-266
# 4477  Wizard-of-Task-diy-272
#
#                                   document_url_question domain_question  \
# 3     https://www.wholefoodsmarket.com/recipes/cream...            food
# 4     https://www.wholefoodsmarket.com/recipes/cream...            food
# 5     https://www.wholefoodsmarket.com/recipes/citru...            food
# 6     https://www.wholefoodsmarket.com/recipes/citru...            food
# 10    https://www.wholefoodsmarket.com/recipes/grill...            food
# ...                                                 ...             ...
# 4461                  https://www.wikihow.com/Dye-Tulle             diy
# 4463  https://www.wikihow.com/Keep-Roaches-Away-from...             diy
# 4471              https://www.wikihow.com/Prune-Verbena             diy
# 4473             https://www.wikihow.com/Grow-Java-Moss             diy
# 4477   https://www.wikihow.com/Grow-English-Ivy-Indoors             diy
#
#                                             text_answer  \
# 3     You will need 1 package of cream cheese and a ...
# 4     I attached them to my last message.  They are ...
# 5     Now transfer to a bowl and serve with the frui...
# 6     You will be using premade pasta.  The recipe c...
# 10    You could make it by hand but this recipe incl...
# ...                                                 ...
# 4461  The leads are the cables coming off of the mul...
# 4463  If one of your diodes don't work we are going ...
# 4471  If it is heated to long it will ruin the integ...
# 4473  You should go ahead and separate all of them. ...
# 4477  Now you just wait to enjoy your delicious home...
#
#                      intent_answer domain_answer question_id
# 3     answer_question_recipe_steps          food    food-2-0
# 4     answer_question_recipe_steps          food    food-2-1
# 5     answer_question_recipe_steps          food    food-3-0
# 6     answer_question_recipe_steps          food    food-3-1
# 10    answer_question_recipe_steps          food    food-4-1
# ...                            ...           ...         ...
# 4461  answer_question_recipe_steps           diy  diy-250-14
# 4463  answer_question_recipe_steps           diy   diy-252-5
# 4471  answer_question_recipe_steps           diy   diy-265-5
# 4473  answer_question_recipe_steps           diy  diy-266-11
# 4477  answer_question_recipe_steps           diy   diy-272-9
#
# [1337 rows x 10 columns]

# %%
with open('./data/internal_questions.json', 'w') as out:
    internal_questions.to_json(out, orient='records')

# %% [markdown]
# #### Scrape recipe data
# You need to be based in the US to run this

# %%
urls = internal_questions['document_url_question'].unique()
len(list(urls))
# Out:
# 499

# %%
import re

def parse_time(time_str):
    class CustomParserInfo(parserinfo):
        HMS = [('h', 'hr', 'hrs', 'hour', 'hours'), ('m', 'min', 'mins', 'minute', 'minutes'),
                ('s', 'second', 'seconds')]

    try:
        parsed_time = dparser.parse(time_str, fuzzy=True, parserinfo=CustomParserInfo())
        parsed_time_min = parsed_time.minute + parsed_time.hour * 60 + parsed_time.second / 60
        return parsed_time_min
    except:
        minutes = ('m', 'min', 'mins', 'minute', 'minutes')
        hours = ('h', 'hr', 'hrs', 'hour', 'hours')
        seconds = ('s', 'second', 'seconds')

        time_num = re.findall(r"\d+", time_str.strip())
        if time_num != []:
            final_time = 0
            time_int = int(time_num[0])
            for word in time_str.split(" "):
                if word in minutes:
                    final_time = time_int
                elif word in hours:
                    final_time = time_int * 60
                elif word in seconds:
                    final_time = time_int / 60

            return final_time
        else:
            return 0


def get_method_number(soup):
        """ Scrape how many methods the DIY article contains and save this number in DIYDocument.number_of_parallel_
        methods
        """
        steps_lists = soup.find_all(class_='steps')
        if steps_lists != []:
            header = steps_lists[0].find('h3')
            if header:
                if "Part" in header.text:
                    # DIY article has parts
                    return 1
                else:
                    # DIY article has methods
                    number = len(steps_lists)
                    return number
            else:
                # DIY article has just one method, no parts
                return 1

def get_steps(soup):
    """ Parse steps. """
    # article just has one method
    list_of_steps_list = soup.find_all('ol', class_='steps_list_2')
    method_number = get_method_number(soup)
    if list_of_steps_list != []:
        # loop through all parts (which include an array of steps) of the article
        if method_number > 1:
            list_of_steps_list = list_of_steps_list[:1]
        for part in list_of_steps_list:
            list_of_steps = get_steps_list(soup, part)
    return list_of_steps

def get_steps_list(soup, steps_list):
    """ Helper function to scrape all steps from list object """
    # Loop over steps object to access associated text, images, or video.
    steps = []
    for step_tag in steps_list.find_all('li'):
        if step_tag.get('id') is not None:
            # Build Step object.
            step_object = step_tag.find(class_='step')
            if step_object:
                # scrape bold step header
                header = step_object.find('b')
                if header:
                    header = header.text

                # scrape all the remaining text after the bold step header
                text = step_object.find_all(text=True)
                if len(text) >= 3:
                    text = text[2]
                    if text[0] == '[':
                        text = ''
                    else:
                        text += ';'
                elif text != []:
                    text = text[0]

                # scrape all step text that is stored in a bulleted list
                step_list_text = step_object.find('ul')
                if step_list_text:
                    for bullet_point in step_list_text.find_all('li'):
                        text += bullet_point.find_all(text=True)[0].strip() + ';'
                steps.append(f'{header}: {text}')
    return steps

# %%
pip install beautifulsoup4 requests
# Out:
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

from bs4 import BeautifulSoup

content = {}

for i,url in enumerate(urls):
    recipe = {}

    request = requests.get(url)
    html = request.text
    status = request.status_code

    if 'wholefoodsmarket' in url and status == 200:
        soup = BeautifulSoup(html, 'html.parser')
        schema = soup.find_all('script', attrs={"type": "application/ld+json"})
        schema = json.loads(schema[0].string)
        recipe['title'] = soup.find(class_='w-header-title').text
        recipe['description'] = schema['description']

        ingredients = []
        for r in schema.get('recipeIngredient'):
            ingredients.append(r)
        recipe['ingredients'] = ingredients

        steps = []
        for r in schema.get('recipeInstructions'):
            steps.append(r.get('text'))
        recipe['steps'] = steps

    elif 'wikihow' in url and status == 200:
        soup = BeautifulSoup(html, 'html.parser')
    
        recipe['title'] = soup.find(id='section_0').text
        recipe['description'] = soup.find(id='mf-section-0').text
        recipe['steps'] = get_steps(soup)

    else:
        print(f'Error for : {url}')

    content[url] = recipe

# %%
with open('./data/scraped_context.json', 'w') as out:
    json.dump(content, out)

content
# Out:
#                                           document_url  \
# 0    https://www.wholefoodsmarket.com/recipes/cream...
# 3    https://www.wholefoodsmarket.com/recipes/citru...
# 4    https://www.wholefoodsmarket.com/recipes/grill...
# 8    https://www.wholefoodsmarket.com/recipes/pasta...
# 11   https://www.wholefoodsmarket.com/recipes/sweet...
# ..                                                 ...
# 814  https://www.wholefoodsmarket.com/recipes/grass...
# 815  https://www.wholefoodsmarket.com/recipes/summe...
# 816  https://www.wholefoodsmarket.com/recipes/cream...
# 819  https://www.wholefoodsmarket.com/recipes/popco...
# 820  https://www.wholefoodsmarket.com/recipes/oatme...
#
#                                              task_data
# 0    {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 3    {'title': 'Citrus Bow Tie Pasta', 'description...
# 4    {'title': 'Grilled Vegetables with Cheese Tort...
# 8    {'title': 'Pasta Alla Norma', 'description': '...
# 11   {'title': 'Sweet and Spicy Tuna Rigatoni', 'de...
# ..                                                 ...
# 814  {'title': 'Grass-Fed Steak with Spring Greens'...
# 815  {'title': 'Summer Squash and Goat Cheese Pizza...
# 816  {'title': 'Creamy Tahini and Broccoli Pasta', ...
# 819  {'title': 'Popcorn Shrimp with Clementine-Chip...
# 820  {'title': 'Oatmeal Coconut Icebox Cookies', 'd...
#
# [404 rows x 2 columns]

# %%
print(len(internal_questions))

content_df = internal_questions.merge(content.rename(columns={"document_url": "document_url_question"}))
print(f'Managed to extract context for {len(content_df)} questions')
# convert task_data to string
content_df.to_json('./data/raw_internal_data.json', orient='records')
content_df
# Out:
# 1337
# Managed to extract context for 1109 questions
#                                                question  \
# 0     How much cream cheese and other ingredients wi...
# 1                   What are the few other ingredients?
# 2     Will I be using premade pasta from the box or ...
# 3           Okay and what other ingredients do I need?
# 4     Should the tortellini be fresh or can I use fr...
# ...                                                 ...
# 1104  Lower your heat to medium-low and cook until t...
# 1105  I have polished each panel, what should I do now?
# 1106  How long should I monitor the cucumber vines f...
# 1107  Black mold is so scary, all the issues it can ...
# 1108  Spray cypress and peppermint oils under and ar...
#
#                      intent_question  \
# 0     ask_question_ingredients_tools
# 1          ask_question_recipe_steps
# 2     ask_question_ingredients_tools
# 3     ask_question_ingredients_tools
# 4          ask_question_recipe_steps
# ...                              ...
# 1104                return_next_step
# 1105               request_next_step
# 1106               request_next_step
# 1107                        chitchat
# 1108                return_next_step
#
#                                                 history  \
# 0
# 1     student: How much cream cheese and other ingre...
# 2
# 3     student: Will I be using premade pasta from th...
# 4     student: Will I be making the tortellini by ha...
# ...                                                 ...
# 1104  teacher: You need to add the broth and pasta a...
# 1105  student: I'm only wanting to do the body, is t...
# 1106  student: I have wrapped the vine tendrils, wha...
# 1107
# 1108  teacher: Spray roach repellent.  | student: I ...
#
#               conversation_id  \
# 0       Wizard-of-Task-food-2
# 1       Wizard-of-Task-food-2
# 2       Wizard-of-Task-food-3
# 3       Wizard-of-Task-food-3
# 4       Wizard-of-Task-food-4
# ...                       ...
# 1104  Wizard-of-Task-food-264
# 1105    Wizard-of-Task-diy-75
# 1106   Wizard-of-Task-diy-143
# 1107   Wizard-of-Task-diy-217
# 1108   Wizard-of-Task-diy-252
#
#                                   document_url_question domain_question  \
# 0     https://www.wholefoodsmarket.com/recipes/cream...            food
# 1     https://www.wholefoodsmarket.com/recipes/cream...            food
# 2     https://www.wholefoodsmarket.com/recipes/citru...            food
# 3     https://www.wholefoodsmarket.com/recipes/citru...            food
# 4     https://www.wholefoodsmarket.com/recipes/grill...            food
# ...                                                 ...             ...
# 1104  https://www.wholefoodsmarket.com/recipes/baby-...            food
# 1105               https://www.wikihow.com/Polish-a-Car             diy
# 1106          https://www.wikihow.com/Trellis-Cucumbers             diy
# 1107        https://www.wikihow.com/Identify-Black-Mold             diy
# 1108  https://www.wikihow.com/Keep-Roaches-Away-from...             diy
#
#                                             text_answer  \
# 0     You will need 1 package of cream cheese and a ...
# 1     I attached them to my last message.  They are ...
# 2     Now transfer to a bowl and serve with the frui...
# 3     You will be using premade pasta.  The recipe c...
# 4     You could make it by hand but this recipe incl...
# ...                                                 ...
# 1104  Yes, you want to do your best to remove as muc...
# 1105  Potted means it is grown in a container and no...
# 1106  Sure. I have shared the next step with you. Ta...
# 1107  We want to water our soil until saturated. Thi...
# 1108  If one of your diodes don't work we are going ...
#
#                      intent_answer domain_answer question_id  \
# 0     answer_question_recipe_steps          food    food-2-0
# 1     answer_question_recipe_steps          food    food-2-1
# 2     answer_question_recipe_steps          food    food-3-0
# 3     answer_question_recipe_steps          food    food-3-1
# 4     answer_question_recipe_steps          food    food-4-1
# ...                            ...           ...         ...
# 1104  answer_question_recipe_steps           diy  food-264-6
# 1105  answer_question_recipe_steps           diy    diy-75-9
# 1106  answer_question_recipe_steps           diy   diy-143-5
# 1107  answer_question_recipe_steps           diy   diy-217-5
# 1108  answer_question_recipe_steps           diy   diy-252-5
#
#                                               task_data
# 0     {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 1     {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 2     {'title': 'Citrus Bow Tie Pasta', 'description...
# 3     {'title': 'Citrus Bow Tie Pasta', 'description...
# 4     {'title': 'Grilled Vegetables with Cheese Tort...
# ...                                                 ...
# 1104  {'title': 'Baby Risotto', 'description': 'Made...
# 1105  {'title': 'How to Polish a Car', 'description'...
# 1106  {'title': 'How to Trellis Cucumbers', 'descrip...
# 1107  {'title': 'How to Identify Black Mold', 'descr...
# 1108  {'title': 'How to Keep Roaches Away from Your ...
#
# [1109 rows x 11 columns]

# %% [markdown]
# ### ANNOTATION STEP
#
# We then annotate the remaining questions:
# - adding the extractive span that answers the question
# - adding a taxonmy to classify questions more granularly
#
# We also remove pairs with inconsistent labels, that require common or external knowledge and pairs that cannot be answered extractively.
# This results in 827 final questions.

# %%
import pandas as pd

# data to annotate - 1109 questions
raw_df = pd.read_json('./data/raw_internal_data.json')
# Out:
# 1109

# %% [markdown]
# ANNOTATION PIPELINE HERE

# %%
# data that has already been annotated
annotated_df = pd.read_json('./data/annotated_data.json', orient='records')

# %%
annotated_df.head()
# Out:
#          conversation_id                                           question  \
# 0  Wizard-of-Task-food-2  How much cream cheese and other ingredients wi...
# 1  Wizard-of-Task-food-2                What are the few other ingredients?
# 2  Wizard-of-Task-food-2                 That's been blended, what's next?
# 3  Wizard-of-Task-food-3  Will I be using premade pasta from the box or ...
# 4  Wizard-of-Task-food-4  Will I be making the tortellini by hand or sho...
#
#     domain                                       document_url  \
# 0  cooking  https://www.wholefoodsmarket.com/recipes/cream...
# 1  cooking  https://www.wholefoodsmarket.com/recipes/cream...
# 2  cooking  https://www.wholefoodsmarket.com/recipes/cream...
# 3  cooking  https://www.wholefoodsmarket.com/recipes/citru...
# 4  cooking  https://www.wholefoodsmarket.com/recipes/grill...
#
#                                      original_answer  \
# 0  You will need 1 package of cream cheese and a ...
# 1  I attached them to my last message.  They are ...
# 2  Now transfer to a bowl and serve with the frui...
# 3  You will be using premade pasta.  The recipe c...
# 4  You could make it by hand but this recipe incl...
#
#                                              history  \
# 0                                               None
# 1  student: How much cream cheese and other ingre...
# 2  student: What are the few other ingredients? |...
# 3                                               None
# 4                                               None
#
#                                            task_data  \
# 0  {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 1  {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 2  {'title': 'Cream Cheese and Cashew Dip', 'desc...
# 3  {'title': 'Citrus Bow Tie Pasta', 'description...
# 4  {'title': 'Grilled Vegetables with Cheese Tort...
#
#                                     extracted_answer  \
# 0  1 (8.0-ounce) package cream cheese, softened\n...
# 1  1/2 cup smooth cashew butter\n2 tablespoons ag...
# 2                       transfer to a bowl and serve
# 3         cook pasta according to package directions
# 4  cook tortellini according to directions on pac...
#
#                question_type
# 0                ['listing']
# 1                ['history']
# 2  ['navigation', 'history']
# 3                ['complex']
# 4                ['complex']

# %% [markdown]
# ### Creating test, train, validation splits

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

df_conversations = annotated_df.groupby('conversation_id').count().reset_index()[['conversation_id','question']].rename(columns={'question':'count'})
df_conversations.loc[32, 'count'] = 6 # for splitting to work properly
df_conversations
# Out:
#             conversation_id  count
# 0      Wizard-of-Task-diy-1      2
# 1     Wizard-of-Task-diy-10      1
# 2    Wizard-of-Task-diy-100      1
# 3    Wizard-of-Task-diy-102      3
# 4    Wizard-of-Task-diy-104      4
# ..                      ...    ...
# 399  Wizard-of-Task-food-93      2
# 400  Wizard-of-Task-food-94      2
# 401  Wizard-of-Task-food-95      2
# 402  Wizard-of-Task-food-98      1
# 403  Wizard-of-Task-food-99      1
#
# [404 rows x 2 columns]

# %%
conversations = list(df_conversations['conversation_id'])
print(len(conversations))
count = list(df_conversations['count'])
print(len(count))

conversation_train, conversation_test, count_train, _ = train_test_split(conversations, count,
                                                               test_size=0.5, random_state = 30, stratify=count)

conversation_train, conversations_val, _, _ = train_test_split(conversation_train, count_train, 
                                                               test_size=0.4, random_state= 42, stratify=count_train)

split_data = annotated_df
split_data['data_split'] = split_data['conversation_id'].apply(lambda x: 'train' if x in conversation_train else 'test' if x in conversation_test else 'validation')
split_data.groupby('data_split').count().reset_index()
# Out:
# 404
# 404
#    data_split  conversation_id  question  domain  document_url  \
# 0        test              412       412     412           412
# 1       train              248       248     248           248
# 2  validation              167       167     167           167
#
#    original_answer  history  task_data  extracted_answer  question_type
# 0              412      375        412               412            412
# 1              248      225        248               248            248
# 2              167      154        167               167            167

# %%
split_data.to_json('./data/final_split_data.json', orient='records')

# %%
split_data['data_split'].value_counts()
# Out:
# data_split
# test          412
# train         248
# validation    167
# Name: count, dtype: int64

# %%
train_df = split_data[split_data['data_split'] == 'train']
print(len(train_df))
train_df.to_json('./data/train.json', orient='records')

val_df = split_data[split_data['data_split'] == 'validation']
print(len(val_df))
val_df.to_json('./data/validation.json', orient='records')

test_df = split_data[split_data['data_split'] == 'test']
print(len(test_df))
test_df.to_json('./data/test.json', orient='records')
# Out:
# 248
# 167
# 412
